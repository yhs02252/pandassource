# %% [markdown]
# #### 시각화
#
#  - 1. matplotlib
#  - 2. pandas
#  - 3. plotly
#  - 4. seaborn

# %%
import matplotlib.pyplot as plt

# 한글폰트
plt.rcParams["font.family"] = "Malgun Gothic"
# - 요소 설정
plt.rcParams["axes.unicode_minus"] = False

# %%
# 기본은 y축
data = [10,20,30,40]
plt.plot(data)

# %%
x = [1,2,3,4]
y = [12,43,25,15]
# p = plt.plot(x,y)
plt.plot(x,y);

# %%
dict1 = {"data_x":[1,2,3,4,5], "data_y":[2,3,5,10,8]}

plt.plot("data_x","data_y", data=dict1)

# %%
dict1 = {"data_x":[1,2,3,4,5], "data_y":[2,3,5,10,8]}

g = plt.plot("data_x","data_y", data=dict1)

# %%
# 차트제목
# plt.title("Chart")
plt.rcParams["font.family"] = "Malgun Gothic"
plt.title("차트")
g = plt.plot("data_x","data_y", data=dict1)

# %%
x = [1,2,3,4]
y = [12,-5,25,15]

plt.rcParams["axes.unicode_minus"] = False

# 변수를 지정하거나 ;를 끝에 붙이면 출력값 예시 안 나옴 
# g = plt.plot(x,y)
plt.plot(x,y);

# %%
plt.plot(x,y)
plt.grid(True)

# %%
plt.plot(x,y)
plt.grid(True, axis="x")

# %%
plt.plot(x,y)
plt.grid(True, axis="y")

# %%
plt.plot(x,y)
plt.title("그래프",fontdict={"size":20})

# 축 제목
plt.xlabel("x축")
plt.ylabel("y축")
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x,y)
plt.title("그래프",fontdict={"size":20})

# 축 제목
plt.xlabel("x축")
plt.ylabel("y축")
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x,y)
plt.title("그래프",fontdict={"size":20})

# 축 제목
plt.xlabel("x축", color="red", loc="right")
plt.ylabel("y축", color="#00aa00", loc="top");

# %%
plt.plot(x,y)
plt.title("그래프",fontdict={"size":20})

# 축 제목
fontdict1 = {"family":"serif","color":"b","weight":"bold","size":14}
fontdict2 = {"family":"D2Coding","color":"deeppink","weight":"bold","size":14}
plt.xlabel("x축", fontdict=fontdict1, labelpad=15)
plt.ylabel("y축", fontdict=fontdict2, labelpad=15);
# Out:
# c:\source\pandassource\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Serif.
#   func(*args, **kwargs)
# c:\source\pandassource\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 축 눈금 설정 : xticks(), yticks()

x = [1,2,3]
y = [2,4,8]

plt.title("chart")
plt.plot(x,y)
plt.xlabel("x축")
plt.ylabel("y축")
plt.xticks([1,2,3])
plt.yticks([3,6,9,12]);

# %%
# 범례 : legend()

x = [1,2,3]
y = [2,4,8]

plt.title("chart")
plt.plot(x,y,label="데이터")
plt.legend();

# %%
x1 = [1,2,3]
x2 = [1,2,3]
y1 = [1,2,3]
y2 = [1,4,7]

plt.plot(x1,y1,color="blue")
plt.plot(x2,y2,color="red")
plt.legend(["data1", "data2"],loc="upper right",fontsize=20,ncol=2);

# %%
x = [1,2,3]
y = [2,4,8]

# linewidth - 선 굵기
plt.plot(x,y, linewidth=10, color = "red")

# %%
plt.plot(x,y,marker="o")

# %%
plt.plot(x,y,"o")

# %%
plt.plot(x,y,linewidth=5, color="red", linestyle=":");

# %%
plt.plot([4,5,6], marker="H")
plt.plot([3,4,5], marker="D")
plt.plot([2,3,4], marker="x")
plt.plot([1,2,3], marker=11)
plt.plot([0,1,2], marker="$Z$")

# %%
plt.plot(x,y,marker="o",markersize=20, markeredgecolor="red", markerfacecolor="yellow");

# %%
plt.plot(x,y,linewidth=5,color="red",linestyle="--");

# %%
plt.plot(x,y,linewidth=5,color="red",linestyle="-.");

# %%
plt.plot(x,y,"ro--") # color, marker, linestyle

# %%
# figure : 그래프 테두리 
plt.figure(figsize=(5,10),facecolor="yellow")
plt.plot(x,y);

# %%
plt.plot(x,y,marker="o")

for idx,txt in enumerate(y):
    plt.text(x[idx], y[idx]+0.2, txt, ha="center",color="blue")

# %%
days = [1,2,3]
az = [2,4,8]
fizer = [5,1,3]
moderna = [1,2,5]

plt.plot(days,az)
plt.plot(days,fizer, marker="o", ls="--")
plt.plot(days,moderna, marker="s", ls="-.")

plt.legend(["az","fizer","moderna"])

# %%
# 수직막대
labels = ["some","thing","is"]
values=[175,107,164]
plt.bar(labels,values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels,values, color="r");

# %%
# colors= ["red","green","blue"]
color = ["red","green","blue"]

plt.bar(labels,values, color=color);

# %%
plt.bar(labels, values,color=color,alpha=0.5);

# %%
plt.bar(labels,values)
plt.ylim(107,180)
# Out:
# (107.0, 180.0)

# %%
plt.bar(labels,values, width=0.5);

# %%
plt.bar(labels,values,width=0.3)
plt.xticks(rotation=45)
plt.yticks(rotation=45);

# %%
plt.bar(labels,values,width=0.3)
plt.xticks(labels=["1번학생","2번학생","3번학생"], ticks=labels, rotation=45);

# %%
# 수평막대

plt.barh(labels, values);

# %%
plt.barh(labels,values)
plt.xlim(60,190);

# %%
# bar 패턴

g = plt.bar(labels, values)
g[0].set_hatch("/")
g[1].set_hatch("x")
g[2].set_hatch("o")

# %%
g = plt.bar(labels, values)
plt.ylim(65,180)

# get_height : 바 높이 가져오기
for idx,y in enumerate(g):
    plt.text(idx, y.get_height()+0.2, values[idx], ha="center",color="blue")

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "이름" : ["채지수","정대만","송태섭","서태웅","강백호","변덕규","황태산","윤대협"],
    "학교" : ["북산고","북산고","북산고","북산고","북산고","능남고","능남고","능남고"],
    "키" : [197,184,168,187,188,202,188,190],
    "국어" : [90,40,80,40,15,80,55,100],
    "영어" : [85,35,75,60,20,100,65,85],
    "수학" : [100,50,70,70,10,95,45,90],
    "과학" : [90,40,80,40,15,80,55,100],
    "사회" : [95,55,80,75,35,85,40,95],
    "SW" : ['python','Java','JavaScript','','','C','VisualBasic','C#'],
}

df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학   과학  사회           SW
# 0  채지수  북산고  197   90   85  100   90  95       python
# 1  정대만  북산고  184   40   35   50   40  55         Java
# 2  송태섭  북산고  168   80   75   70   80  80   JavaScript
# 3  서태웅  북산고  187   40   60   70   40  75
# 4  강백호  북산고  188   15   20   10   15  35
# 5  변덕규  능남고  202   80  100   95   80  85            C
# 6  황태산  능남고  188   55   65   45   55  40  VisualBasic
# 7  윤대협  능남고  190  100   85   90  100  95           C#

# %%
plt.plot(df['이름'],df["국어"]);

# %%
plt.bar(df["이름"], df["국어"])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(df['이름'],df["국어"]);
plt.plot(df['이름'],df["수학"]);
plt.plot(df['이름'],df["영어"]);

# %%
plt.bar(df['이름'],df["국어"]);
plt.bar(df['이름'],df["수학"]);
plt.bar(df['이름'],df["영어"]);

# %%
df.to_csv("./resources/student.csv", index=False)

# %%
student_df = pd.read_csv("./resources/student.csv")
student_df
# Out:
#     이름   학교    키   국어   영어   수학   과학  사회           SW
# 0  채지수  북산고  197   90   85  100   90  95       python
# 1  정대만  북산고  184   40   35   50   40  55         Java
# 2  송태섭  북산고  168   80   75   70   80  80   JavaScript
# 3  서태웅  북산고  187   40   60   70   40  75          NaN
# 4  강백호  북산고  188   15   20   10   15  35          NaN
# 5  변덕규  능남고  202   80  100   95   80  85            C
# 6  황태산  능남고  188   55   65   45   55  40  VisualBasic
# 7  윤대협  능남고  190  100   85   90  100  95           C#

# %%
# 누적막대그래프


plt.bar(df['이름'],df["국어"]);
plt.bar(df['이름'],df["영어"], bottom=student_df["국어"]);

# %%
student_df.shape[0]

np.arange(student_df.shape[0])
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
# 다중막대그래프
w = 0.25
index = np.arange(student_df.shape[0])

plt.bar(index - w, df["국어"],width=w)
plt.bar(index, df["영어"],width=w)
plt.bar(index + w, df["수학"],width=w);
plt.legend(["국어","영어","수학"])

# %% [markdown]
# #### 원 그래프

# %%
values = [30,25,20,13,10,2]
labels = ['python','Java','JavaScript','C#','C++','etc']

# startangle : 원하는 각도에서 시작할 수 있으나 각도를 주면 시계 반대 방향으로 그려짐
# counterclock : 시계 방향으로 원 작성
plt.pie(values,labels=labels, startangle=90, counterclock=False, autopct="%.1f%%");

# %%
[0.05] * 6
# Out:
# [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# %%
# explode = [0.2,0.1,0,0,0,0]
explode = [0.05]*6

plt.pie(values,labels=labels, startangle=90, counterclock=False, autopct="%.1f%%", explode=explode);

# %%
plt.pie(values, labels=labels, startangle=90, counterclock=False, autopct="%.1f%%", explode=explode)
g=plt.legend(loc=(1.2,0.3),title="언어별 선호도")

# %%
colors = ["#ffadad","#ffd6a5","#fdffb6","#caffbf","#9bf6ff","#a0c4ff"]
plt.pie(values, labels=labels, startangle=90, counterclock=False, autopct="%.1f%%", explode=explode, colors=colors);

# %%
wedgeprops = {"width":0.8}
plt.pie(values, labels=labels, startangle=90, counterclock=False, autopct="%.1f%%", explode=explode, colors=colors, wedgeprops=wedgeprops);

# %%
wedgeprops = {"width":0.8, "edgecolor":"w", "linewidth":3}
plt.pie(values, labels=labels, startangle=90, counterclock=False, autopct="%.1f%%", colors=colors, wedgeprops=wedgeprops);

# %%
def custom_autopct(pct):
    return ("%.1f%%" % pct) if pct >=10 else ""

wedgeprops = {"width":0.8, "edgecolor":"w", "linewidth":3}
plt.pie(values, labels=labels, startangle=90, counterclock=False, autopct=custom_autopct, colors=colors, wedgeprops=wedgeprops);

# %%
# student 학교 점유율 원 차트로 자겅
student_df = pd.read_csv("./resources/student.csv")
grp = student_df.groupby("학교").size()
grp
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
values = [grp["북산고"],grp["능남고"]]
labels = ["북산고","능산고"]

plt.pie(values,labels=labels, autopct="%.1f%%")
g=plt.title("소속학교")

# %% [markdown]
# #### 선점도 그래프
#
#  - 2개 수치 그래프

# %%
plt.scatter(student_df["영어"], student_df["수학"])
plt.xlabel("영어")
plt.ylabel("수학");

# %%
# 학년 컬럼 추가

student_df["학년"] = [3,3,2,1,1,3,2,2]

# %%
sizes = student_df["학년"] * 500

plt.scatter(student_df["영어"],student_df["수학"],s=sizes)
plt.xlabel("영어")
plt.ylabel("수학");

# %%
# cmap="viridis", c=student_df["학년"] : 학년별로 색상 구별
size = student_df["학년"]*500

plt.scatter(student_df["영어"],student_df["수학"], s=size, cmap="viridis", c=student_df["학년"])
plt.xlabel("영어")
plt.ylabel("수학")
# Out:
# Text(0, 0.5, '수학')

# %%
# cmap="viridis", c=student_df["학년"] : 학년별로 색상 구별
size = student_df["학년"]*500

plt.scatter(student_df["영어"],student_df["수학"], s=size, cmap="viridis", c=student_df["학년"],alpha=0.3)
plt.xlabel("영어")
plt.ylabel("수학")
# Out:
# Text(0, 0.5, '수학')

# %% [markdown]
# #### 혼합형 그래프
#
#  - subplots

# %%
# 2행 2열 그래프 작성 - 국어(bar), 영어, 수학(plot), 키(barh), 사회(plot)

# (<Figure size 1500x1000 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

fig,axes = plt.subplots(2, 2, figsize=(15,10))

# 첫번째 차트
axes[0,0].bar(student_df["이름"],student_df["국어"])
axes[0,0].set_title("학생별 국어 점수")
axes[0,0].legend(["국어점수"])
axes[0,0].grid(linestyle="--", linewidth = 0.5)
axes[0,0].set_facecolor("lightyellow")

# 두번째 차트
axes[0,1].plot(student_df["이름"],student_df["영어"])
axes[0,1].plot(student_df["이름"],student_df["수학"])
axes[0,1].set_title("학생별 영어/수학 점수")
axes[0,1].legend(["영어점수", "수학점수"])

# 세번째 차트
axes[1,0].barh(student_df["이름"], student_df["키"])
axes[1,0].set_title("학생별 키")

# 네번째 차트
axes[1,1].plot(student_df["이름"],student_df["사회"])

# %%
# 데이터프레임 생성
movie_df = pd.DataFrame({
    "영화" : ["명량","극한직업","신과함계 - 죄와 별","국제시장","베테랑","괴물","도둑들","7번방의 선물","암살","광해, 왕이 된 남자"],
    "개봉 연도" : [2014,2019,2017,2014,2015,2006,2012,2013,2015,2012],
    "관객수" : [1761,1626,1441,1425,1341,1301,1298,1281,1270,1231],
    "평점" : [8.88,9.20,8.73,9.16,9.24,8.62,7.64,8.83,9.10,9.25],
})

movie_df
# Out:
#             영화  개봉 연도   관객수    평점
# 0           명량   2014  1761  8.88
# 1         극한직업   2019  1626  9.20
# 2  신과함계 - 죄와 별   2017  1441  8.73
# 3         국제시장   2014  1425  9.16
# 4          베테랑   2015  1341  9.24
# 5           괴물   2006  1301  8.62
# 6          도둑들   2012  1298  7.64
# 7      7번방의 선물   2013  1281  8.83
# 8           암살   2015  1270  9.10
# 9  광해, 왕이 된 남자   2012  1231  9.25

# %%
# 영화 데이터프레임 이용한 차트 작성
# x축은 영화명, y축은 평점인 bar차트
plt.figure(figsize=(15,5))
plt.bar(movie_df["영화"], movie_df["평점"])
# Out:
# <BarContainer object of 10 artists>

# %%
# 차트 세부설정
# 제목 : 국내 Top 10 영화 평점 정보
# x축 래이블명 : 영화
# y축 레이블명 : 평점
# x축 영화명은 45도 각도로 설정
plt.bar(movie_df["영화"], movie_df["평점"])
plt.title("국내 Top 10 영화 평점 정보")
plt.xlabel("영화")
plt.ylabel("평점")
plt.xticks(rotation=90)
plt.ylim(7,10)
# Out:
# (7.0, 10.0)

# %%
# 개봉 연도별 평점 변화 추이를 선 차트로 작성
# 연도별 평균 평점을 구한 뒤 그래프로 작성
# x 축 :  개봉연도, y축 : 평점

# 연도별 평균 평점 구하기
df1 = movie_df.groupby("개봉 연도")["평점"].mean().reset_index()
df1

# 그래프 작성
plt.plot(df1["개봉 연도"], df1["평점"])

# %%
plt.plot(df1["개봉 연도"], df1["평점"], marker="o")
plt.xticks([2005,2010,2015,2020])
plt.ylim(top=10,bottom=7)
# Out:
# (7.0, 10.0)

# %%
# 평점이 9점 이상인 영화의 비율을 확인할 수 있는 원 차트 작성

# 9점 이상
condition = movie_df["평점"] >= 9.0
condition
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: 평점, dtype: bool

# %%
# 9점이상
movie_df[condition]

# 9점이하
movie_df[~condition]
# Out:
#             영화  개봉 연도   관객수    평점
# 0           명량   2014  1761  8.88
# 2  신과함계 - 죄와 별   2017  1441  8.73
# 5           괴물   2006  1301  8.62
# 6          도둑들   2012  1298  7.64
# 7      7번방의 선물   2013  1281  8.83

# %%
values = [len(movie_df[condition]), len(movie_df[~condition])]

plt.pie(values, labels=["9점이상","9점미만"],autopct="%.1f%%")
plt.legend(loc=(1,0.3));
